# %%
# a = "a|q|w|e|r|t|y|u|i|o|p|a|s|d|f|g|h|j|k|l|z|x|c|v|b|n|m"
#
# print(a.split("|"))
# #1
# a = input("isminggizni kiriting: ")
# print("".join(reversed(a)))
#
# #2
# email = input("emailinggizni kiriting: ")
# print(email.split("@")[1])
#
# #3

#4
# soz = input("so'z kiriting; ")
# print(soz == soz[:: -1])

#5
# matin = input("matin kiriting; ")
# print(len(matin.split()))

#6
# matn = input("matn kiriting; ")
# raqamlar = ''.join([ch forcchnin matin if ch.isdigit()])
# print(raqamlar)

#7
# matin = input("Matin kiriting; ")
# print(matin.title())

#8
# import re
#
# matin = input("matin kiriting; ")
# emails = re.findall(r"oldioldi@gmail.com", matin)
# print(emails)
